# %% [markdown]
# # Lab 7- Data Analysis

# %% [markdown]
# ## Exercise 1: Reading
#
# ### HiggsML
# In 2014, some of my colleagues from the ATLAS experiment put together a Higgs Machine Learning Challenge, which was hosted on [Kaggle](https://www.kaggle.com). Please read sections 1 and 3 (skip/skim 2) of [The HiggsML Technical Documentation](https://higgsml.lal.in2p3.fr/files/2014/04/documentation_v1.8.pdf).
#
# Kaggle is a platform for data science competitions, with cash awards for winners. Kaggle currently hosts over 50,000 public datasets and associated competitions. Later in the course we will look at a variety of problems hosted on Kaggle and similar platforms.
#
# ### SUSY Dataset
#
# For the next few labs we will use datasets used in the [first paper on Deep Learning in High Energy physics](https://arxiv.org/pdf/1402.4735.pdf). Please read up to the "Deep Learning" section (end of page 5). This paper demonstrates that Deep Neural Networks can learn from raw data the features that are typically used by physicists for searches for exotics particles. The authors provide the data they used for this paper. They considered two benchmark scenarios: Higgs and SUSY.

# %% [markdown]
# ## Exercise 2: Download SUSY Dataset
#
# The information about the dataset can be found at the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/index.php). We'll start with the [SUSY Dataset](https://archive.ics.uci.edu/ml/datasets/SUSY).
#
# ### Download
# In a terminal, download the data directly from the source and then decompress it. For example:

# %% [markdown]
# * To download:
#     * On Mac OS:
#     `curl http://archive.ics.uci.edu/ml/machine-learning-databases/00279/SUSY.csv.gz > SUSY.csv.gz`
#
#     * In linux:
#     `wget http://archive.ics.uci.edu/ml/machine-learning-databases/00279/SUSY.csv.gz`
#
# * To uncompress:
# `gunzip SUSY.csv.gz`

# %%
#!curl http://archive.ics.uci.edu/ml/machine-learning-databases/00279/SUSY.csv.gz > SUSY.csv.gz

# %%
#!rm SUSY.csv

# %%
#!gunzip SUSY.csv.gz

# %%
ls -lh
# Out:
# total 4698696
# -rw-r--r--@ 1 tommysanders  staff   398K Mar 26 19:57 Lab.7.ipynb
# -rw-r--r--  1 tommysanders  staff   8.0M Mar 26 19:45 Lab.7.pdf
# -rw-r--r--  1 tommysanders  staff     0B Mar 26 20:19 SUSY-small.csv
# -rw-r--r--  1 tommysanders  staff   2.2G Mar 26 20:17 SUSY.csv

# %% [markdown]
# The data is provided as a comma separated file.

# %%
filename="SUSY.csv"
# print out the first 5 lines using unix head command
# !head -5  "SUSY.csv"
# Out:
# 0.000000000000000000e+00,9.728614687919616699e-01,6.538545489311218262e-01,1.176224589347839355e+00,1.157156467437744141e+00,-1.739873170852661133e+00,-8.743090629577636719e-01,5.677649974822998047e-01,-1.750000417232513428e-01,8.100607395172119141e-01,-2.525521218776702881e-01,1.921887040138244629e+00,8.896374106407165527e-01,4.107718467712402344e-01,1.145620822906494141e+00,1.932632088661193848e+00,9.944640994071960449e-01,1.367815494537353516e+00,4.071449860930442810e-02
# 1.000000000000000000e+00,1.667973041534423828e+00,6.419061869382858276e-02,-1.225171446800231934e+00,5.061022043228149414e-01,-3.389389812946319580e-01,1.672542810440063477e+00,3.475464344024658203e+00,-1.219136357307434082e+00,1.295456290245056152e-02,3.775173664093017578e+00,1.045977115631103516e+00,5.680512785911560059e-01,4.819284379482269287e-01,0.000000000000000000e+00,4.484102725982666016e-01,2.053557634353637695e-01,1.321893453598022461e+00,3.775840103626251221e-01
# 1.000000000000000000e+00,4.448399245738983154e-01,-1.342980116605758667e-01,-7.099716067314147949e-01,4.517189264297485352e-01,-1.613871216773986816e+00,-7.686609029769897461e-01,1.219918131828308105e+00,5.040258169174194336e-01,1.831247568130493164e+00,-4.313853085041046143e-01,5.262832045555114746e-01,9.415140151977539062e-01,1.587535023689270020e+00,2.024308204650878906e+00,6.034975647926330566e-01,1.562373995780944824e+00,1.135454416275024414e+00,1.809100061655044556e-01
# 1.000000000000000000e+00,3.812560737133026123e-01,-9.761453866958618164e-01,6.931523084640502930e-01,4.489588439464569092e-01,8.917528986930847168e-01,-6.773284673690795898e-01,2.033060073852539062e+00,1.533040523529052734e+00,3.046259880065917969e+00,-1.005284786224365234e+00,5.693860650062561035e-01,1.015211343765258789e+00,1.582216739654541016e+00,1.551914215087890625e+00,7.612152099609375000e-01,1.715463757514953613e+00,1.492256760597229004e+00,9.071890264749526978e-02
# 1.000000000000000000e+00,1.309996485710144043e+00,-6.900894641876220703e-01,-6.762592792510986328e-01,1.589282631874084473e+00,-6.933256387710571289e-01,6.229069828987121582e-01,1.087561845779418945e+00,-3.817416727542877197e-01,5.892043709754943848e-01,1.365478992462158203e+00,1.179295063018798828e+00,9.682182073593139648e-01,7.285631299018859863e-01,0.000000000000000000e+00,1.083157896995544434e+00,4.342924803495407104e-02,1.154853701591491699e+00,9.485860168933868408e-02

# %% [markdown]
# ## Reducing the dataset
#
# This is a rather large dataset. If you have trouble loading it, we can easily make a new file with less data.
#
# Here we look at the size of the data

# %%
# !ls -lh
# Out:
# total 4698696
# -rw-r--r--@ 1 tommysanders  staff   398K Mar 26 19:57 Lab.7.ipynb
# -rw-r--r--  1 tommysanders  staff   8.0M Mar 26 19:45 Lab.7.pdf
# -rw-r--r--  1 tommysanders  staff     0B Mar 26 20:19 SUSY-small.csv
# -rw-r--r--  1 tommysanders  staff   2.2G Mar 26 20:17 SUSY.csv

# %% [markdown]
# We see that we have 5 million datapoints.

# %%
# !wc -l SUSY.csv
# Out:
#  5000000 SUSY.csv

# %% [markdown]
# We create a new file of the first half million. This is sufficient for our needs in this lab:

# %%
# !head -500000 SUSY.csv > SUSY-small.csv

# %%
ls -lh
# Out:
# total 5190344
# -rw-r--r--@ 1 tommysanders  staff   398K Mar 26 19:57 Lab.7.ipynb
# -rw-r--r--  1 tommysanders  staff   8.0M Mar 26 19:45 Lab.7.pdf
# -rw-r--r--  1 tommysanders  staff   228M Mar 26 20:22 SUSY-small.csv
# -rw-r--r--  1 tommysanders  staff   2.2G Mar 26 20:17 SUSY.csv

# %%
! wc -l SUSY-small.csv
# Out:
#   500000 SUSY-small.csv

# %% [markdown]
# Use this file for the rest of the lab to make this run faster.

# %% [markdown]
# ### First Look
#
# Each row represents a LHC collision event. Each column contains some observable from that event. The variable names are ([based on documentation](https://archive.ics.uci.edu/ml/datasets/SUSY)):

# %%
VarNames=["signal", "l_1_pT", "l_1_eta","l_1_phi", "l_2_pT", "l_2_eta", "l_2_phi", "MET", "MET_phi", "MET_rel", "axial_MET", "M_R", "M_TR_2", "R", "MT2", "S_R", "M_Delta_R", "dPhi_r_b", "cos_theta_r1"]

# %% [markdown]
# Some of these variables represent the "raw" kinematics of the observed final state particles, while others are "features" that are derived from these raw quantities:

# %%
RawNames=["l_1_pT", "l_1_eta","l_1_phi", "l_2_pT", "l_2_eta", "l_2_phi", "MET", "MET_phi"]
FeatureNames=list(set(VarNames[1:]).difference(RawNames))

# %%
RawNames
# Out:
# ['l_1_pT',
#  'l_1_eta',
#  'l_1_phi',
#  'l_2_pT',
#  'l_2_eta',
#  'l_2_phi',
#  'MET',
#  'MET_phi']

# %%
FeatureNames
# Out:
# ['dPhi_r_b',
#  'cos_theta_r1',
#  'MT2',
#  'S_R',
#  'M_R',
#  'R',
#  'MET_rel',
#  'M_TR_2',
#  'axial_MET',
#  'M_Delta_R']

# %% [markdown]
# We will use pandas to read in the file, and matplotlib to make plots. The following ensures pandas is installed and sets everything up:

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Now we can read the data into a pandas dataframe:

# %%
filename = "SUSY.csv"
df = pd.read_csv(filename, dtype='float64', names=VarNames)

# %% [markdown]
# You can see the data in Jupyter by just evaluateing the dataframe:

# %%
df
# Out:
#          signal    l_1_pT   l_1_eta   l_1_phi    l_2_pT   l_2_eta   l_2_phi  \
# 0           0.0  0.972861  0.653855  1.176225  1.157156 -1.739873 -0.874309
# 1           1.0  1.667973  0.064191 -1.225171  0.506102 -0.338939  1.672543
# 2           1.0  0.444840 -0.134298 -0.709972  0.451719 -1.613871 -0.768661
# 3           1.0  0.381256 -0.976145  0.693152  0.448959  0.891753 -0.677328
# 4           1.0  1.309996 -0.690089 -0.676259  1.589283 -0.693326  0.622907
# ...         ...       ...       ...       ...       ...       ...       ...
# 4999995     1.0  0.853325 -0.961783 -1.487277  0.678190  0.493580  1.647969
# 4999996     0.0  0.951581  0.139370  1.436884  0.880440 -0.351948 -0.740852
# 4999997     0.0  0.840389  1.419162 -1.218766  1.195631  1.695645  0.663756
# 4999998     1.0  1.784218 -0.833565 -0.560091  0.953342 -0.688969 -1.428233
# 4999999     0.0  0.761500  0.680454 -1.186213  1.043521 -0.316755  0.246879
#
#               MET   MET_phi   MET_rel  axial_MET       M_R    M_TR_2  \
# 0        0.567765 -0.175000  0.810061  -0.252552  1.921887  0.889637
# 1        3.475464 -1.219136  0.012955   3.775174  1.045977  0.568051
# 2        1.219918  0.504026  1.831248  -0.431385  0.526283  0.941514
# 3        2.033060  1.533041  3.046260  -1.005285  0.569386  1.015211
# 4        1.087562 -0.381742  0.589204   1.365479  1.179295  0.968218
# ...           ...       ...       ...        ...       ...       ...
# 4999995  1.843867  0.276954  1.025105  -1.486535  0.892879  1.684429
# 4999996  0.290863 -0.732360  0.001360   0.257738  0.802871  0.545319
# 4999997  0.490888 -0.509186  0.704289   0.045744  0.825015  0.723530
# 4999998  2.660703 -0.861344  2.116892   2.906151  1.232334  0.952444
# 4999999  1.120280  0.998479  1.640881  -0.797688  0.854212  1.121858
#
#                 R       MT2       S_R  M_Delta_R  dPhi_r_b  cos_theta_r1
# 0        0.410772  1.145621  1.932632   0.994464  1.367815      0.040714
# 1        0.481928  0.000000  0.448410   0.205356  1.321893      0.377584
# 2        1.587535  2.024308  0.603498   1.562374  1.135454      0.180910
# 3        1.582217  1.551914  0.761215   1.715464  1.492257      0.090719
# 4        0.728563  0.000000  1.083158   0.043429  1.154854      0.094859
# ...           ...       ...       ...        ...       ...           ...
# 4999995  1.674084  3.366298  1.046707   2.646649  1.389226      0.364599
# 4999996  0.602730  0.002998  0.748959   0.401166  0.443471      0.239953
# 4999997  0.778236  0.752942  0.838953   0.614048  1.210595      0.026692
# 4999998  0.685846  0.000000  0.781874   0.676003  1.197807      0.093689
# 4999999  1.165438  1.498351  0.931580   1.293524  1.539167      0.187496
#
# [5000000 rows x 19 columns]

# %% [markdown]
# The first column stores the "truth" label of whether an event was signal or not. Pandas makes it easy to create dataframes that store only the signal or background events:

# %%
df_sig=df[df.signal==1]
df_bkg=df[df.signal==0]

# %% [markdown]
# The following example plots the signal and background distributions of every variable. Note that we use VarNames[1:] to skip the first variable, which was the true label.

# %%
import numpy as np
for var in VarNames[1:]:
    print (var)
    plt.figure(figsize=(10,5))
    plt.hist(np.array(df_sig[var]),bins=100,histtype="step", color="red",label="signal",density=1, stacked=True)
    plt.hist(np.array(df_bkg[var]),bins=100,histtype="step", color="blue", label="background",density=1, stacked=True)
    plt.legend(loc='upper right')
    plt.show()
# Out:
# l_1_pT
# l_1_eta
# l_1_phi
# l_2_pT
# l_2_eta
# l_2_phi
# MET
# MET_phi
# MET_rel
# axial_MET
# M_R
# M_TR_2
# R
# MT2
# S_R
# M_Delta_R
# dPhi_r_b
# cos_theta_r1

# %% [markdown]
# ## Exercise 3: Make nice figures
#
# Now use `matplotlib` to reproduce as closely as you can figures 5 and 6 from the paper. This exercise is intended to get you to familiarize yourself with making nicely formatted `matplotlib` figures with multiple plots. Note that the plots in the paper are actually wrong!

# %%
# Create 5x4 subplot grid that flattens axes array for easy indexing
fig, axes = plt.subplots(5, 4, figsize=(20,25))
axes = axes.ravel()

# Loop through features and plots normalized histograms on each subplot
for i, feat in enumerate(FeatureNames):
    axes[i].hist(df_sig[feat], bins=50, alpha=0.5, label='Signal', density=True)
    axes[i].hist(df_bkg[feat], bins=50, alpha=0.5, label='Background', density=True)
    axes[i].set_title(feat)  # Labels each plot with feature name
    axes[i].legend()         # Adds signal/bkg legend

plt.tight_layout()  # Fixes spacing between subplots
plt.show()          # Displays the figure

# %% [markdown]
# ## Exercise 4: Correlation
#
# ### Exercise 4.1
#
# #### Part a
# Write a function that creates pair plots and use it to compare variables in the SUSY sample, separately for low and high-level features. Refer to Lecture 13 for details. Do not use `seaborn`.
#
# #### Part b
# Making these plots can be slow because creating each plot initiates a full loop over the data. Make at least one modification to your function in part a to speed it up. Can you propose a different method of creating histograms that would speed up making such pair plots?
#
# #### Part c
# Which observables appear to be best for separating signal from background?

# %%
# Part a: Complete low-level features pair plot (1 cell)
def compare_distributions(df, feature, alpha=0.5, density=1, bins=50):
    """Diagonal histograms: signal vs background"""
    plt.hist(df[df['signal']==1][feature], bins=bins, alpha=alpha, label='Signal', density=density)
    plt.hist(df[df['signal']==0][feature], bins=bins, alpha=alpha, label='Background', density=density)
    plt.legend()

def compare_scatter(df, x_var, y_var, make_legend=True):
    """Off-diagonal scatter: signal (blue) vs background (red)"""
    plt.scatter(df[df['signal']==1][x_var], df[df['signal']==1][y_var], alpha=0.3, s=1, c='blue', label='Signal')
    plt.scatter(df[df['signal']==0][x_var], df[df['signal']==0][y_var], alpha=0.3, s=1, c='red', label='Background')
    if make_legend: plt.legend()

# Low-level raw features pair plot like Lecture 13
columns = df.columns[1:6]  # l_1_pT through l_2_eta (5 raw kinematics)
n_columns = len(columns)
plt.figure(figsize=(15,15))

plot_i = 0
for i, x_var_name in enumerate(columns):
    for j, y_var_name in enumerate(columns):
        plot_i += 1
        plt.subplot(n_columns, n_columns, plot_i)
        make_legend = plot_i == 1  # Legend only on first subplot
        if i == j:
            compare_distributions(df, x_var_name)
        else:
            compare_scatter(df, x_var_name, y_var_name, make_legend=make_legend)

plt.tight_layout()
plt.show()

# %%
#Sample data first like Lecture 16 
sample_size = 50000  # 10% of SUSY-small.csv
df_sample = df.sample(n=sample_size, random_state=42)

# High-level features pair plot (faster with sampling)
columns = FeatureNames[:5]  # First 5 derived features
n_columns = len(columns)
plt.figure(figsize=(15,15))

plot_i = 0
for i, x_var_name in enumerate(columns):
    for j, y_var_name in enumerate(columns):
        plot_i += 1
        plt.subplot(n_columns, n_columns, plot_i)
        make_legend = plot_i == 1
        if i == j:
            compare_distributions(df_sample, x_var_name)  # Use sampled data
        else:
            compare_scatter(df_sample, x_var_name, y_var_name, make_legend=make_legend)

plt.tight_layout()
plt.show()

# %% [markdown]
# M_R, MT2, and M_TR_2 best separate signal from background. They show clear signal peaks away from background tails in histograms and form tight signal clusters in pair plots. Raw kinematics like lepton pT/eta have too much overlap between classes.

# %% [markdown]
# ### Exercise 4.2
#
# #### Part a
# Install [tabulate](https://github.com/astanin/python-tabulate).
#
# #### Part b
# Use numpy to compute the [covariance matrix](https://numpy.org/doc/stable/reference/generated/numpy.cov.html) and [correlation matrix](https://numpy.org/doc/stable/reference/generated/numpy.corrcoef.html) between all observabes, and separately between low and high-level features.
#
# #### Part c
# Use tabulate to create a well formatted table of the covariance and correlation matrices, with nice headings and appropriate significant figures. Embed the table into this notebook.
#
# #### Part d
# Write a function that takes a dataset and appropriate arguments and performs steps b and c.

# %%
pip install tabulate
# Out:
# Requirement already satisfied: tabulate in /opt/homebrew/Cellar/jupyterlab/4.4.6/libexec/lib/python3.13/site-packages (0.10.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Low-level raw features
low_features = df[RawNames].values.T
cov_low = np.cov(low_features)
corr_low = np.corrcoef(low_features)

print("Covariance:\n", cov_low.round(3))
print("\nCorrelation:\n", corr_low.round(3))
print()

# High-level derived features
high_features = df[FeatureNames].values.T
cov_high = np.cov(high_features)
corr_high = np.corrcoef(high_features)

print("Covariance:\n", cov_high.round(3))
print("\nCorrelation:\n", corr_high.round(3))
# Out:
# Covariance:
#  [[ 4.720e-01 -0.000e+00 -0.000e+00  3.080e-01 -0.000e+00  0.000e+00
#    2.310e-01 -1.000e-03]
#  [-0.000e+00  1.006e+00  0.000e+00 -0.000e+00  4.060e-01  0.000e+00
#   -1.000e-03 -1.000e-03]
#  [-0.000e+00  0.000e+00  1.003e+00 -0.000e+00  1.000e-03 -2.680e-01
#    1.000e-03 -1.840e-01]
#  [ 3.080e-01 -0.000e+00 -0.000e+00  4.280e-01 -0.000e+00  0.000e+00
#    8.000e-02 -1.000e-03]
#  [-0.000e+00  4.060e-01  1.000e-03 -0.000e+00  1.006e+00 -0.000e+00
#    0.000e+00 -0.000e+00]
#  [ 0.000e+00  0.000e+00 -2.680e-01  0.000e+00 -0.000e+00  1.003e+00
#    0.000e+00 -3.400e-02]
#  [ 2.310e-01 -1.000e-03  1.000e-03  8.000e-02  0.000e+00  0.000e+00
#    7.620e-01 -2.000e-03]
#  [-1.000e-03 -1.000e-03 -1.840e-01 -1.000e-03 -0.000e+00 -3.400e-02
#   -2.000e-03  1.003e+00]]
#
# Correlation:
#  [[ 1.    -0.    -0.     0.685 -0.     0.     0.385 -0.001]
#  [-0.     1.     0.    -0.001  0.403  0.    -0.001 -0.001]
#  [-0.     0.     1.    -0.     0.001 -0.267  0.001 -0.184]
#  [ 0.685 -0.001 -0.     1.    -0.001  0.     0.14  -0.002]
#  [-0.     0.403  0.001 -0.001  1.    -0.     0.    -0.   ]
#  [ 0.     0.    -0.267  0.    -0.     1.     0.    -0.034]
#  [ 0.385 -0.001  0.001  0.14   0.     0.     1.    -0.002]
#  [-0.001 -0.001 -0.184 -0.002 -0.    -0.034 -0.002  1.   ]]
#
# Covariance:
#  [[ 0.19   0.009  0.021 -0.004 -0.029  0.087  0.147  0.058 -0.026  0.042]
#  [ 0.009  0.039  0.045 -0.01  -0.014  0.058  0.056  0.052 -0.054  0.039]
#  [ 0.021  0.045  0.738 -0.011 -0.037  0.232  0.41   0.189 -0.46   0.433]
#  [-0.004 -0.01  -0.011  0.385  0.383 -0.083  0.082  0.23  -0.043  0.096]
#  [-0.029 -0.014 -0.037  0.383  0.395 -0.113  0.044  0.212  0.015  0.074]
#  [ 0.087  0.058  0.232 -0.083 -0.113  0.222  0.25   0.104 -0.182  0.166]
#  [ 0.147  0.056  0.41   0.082  0.044  0.25   0.792  0.303 -0.125  0.416]
#  [ 0.058  0.052  0.189  0.23   0.212  0.104  0.303  0.341 -0.189  0.242]
#  [-0.026 -0.054 -0.46  -0.043  0.015 -0.182 -0.125 -0.189  1.003 -0.234]
#  [ 0.042  0.039  0.433  0.096  0.074  0.166  0.416  0.242 -0.234  0.389]]
#
# Correlation:
#  [[ 1.     0.106  0.056 -0.013 -0.106  0.424  0.378  0.228 -0.06   0.156]
#  [ 0.106  1.     0.263 -0.084 -0.115  0.627  0.317  0.451 -0.274  0.319]
#  [ 0.056  0.263  1.    -0.021 -0.068  0.574  0.536  0.378 -0.535  0.808]
#  [-0.013 -0.084 -0.021  1.     0.981 -0.285  0.149  0.636 -0.07   0.248]
#  [-0.106 -0.115 -0.068  0.981  1.    -0.381  0.078  0.578  0.024  0.189]
#  [ 0.424  0.627  0.574 -0.285 -0.381  1.     0.595  0.38  -0.385  0.564]
#  [ 0.378  0.317  0.536  0.149  0.078  0.595  1.     0.583 -0.141  0.749]
#  [ 0.228  0.451  0.378  0.636  0.578  0.38   0.583  1.    -0.323  0.666]
#  [-0.06  -0.274 -0.535 -0.07   0.024 -0.385 -0.141 -0.323  1.    -0.375]
#  [ 0.156  0.319  0.808  0.248  0.189  0.564  0.749  0.666 -0.375  1.   ]]

# %%
from IPython.display import HTML, display
import tabulate

#Low-level covariance/correlation as HTML tables
low_features = df[RawNames].values.T
cov_low = np.cov(low_features).round(3)
corr_low = np.corrcoef(low_features).round(3)

print("Low-level Raw Features")
display(HTML(tabulate.tabulate(cov_low, tablefmt='html', headers=RawNames)))
display(HTML(tabulate.tabulate(corr_low, tablefmt='html', headers=RawNames)))

# High-level derived features
high_features = df[FeatureNames].values.T
cov_high = np.cov(high_features).round(3)
corr_high = np.corrcoef(high_features).round(3)

print("\nHigh-level Derived Features") 
display(HTML(tabulate.tabulate(cov_high, tablefmt='html', headers=FeatureNames)))
display(HTML(tabulate.tabulate(corr_high, tablefmt='html', headers=FeatureNames)))
# Out:
# Low-level Raw Features
# <table>
# <thead>
# <tr><th style="text-align: right;">  l_1_pT</th><th style="text-align: right;">  l_1_eta</th><th style="text-align: right;">  l_1_phi</th><th style="text-align: right;">  l_2_pT</th><th style="text-align: right;">  l_2_eta</th><th style="text-align: right;">  l_2_phi</th><th style="text-align: right;">   MET</th><th style="text-align: right;">  MET_phi</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">   0.472</td><td style="text-align: right;">   -0    </td><td style="text-align: right;">   -0    </td><td style="text-align: right;">   0.308</td><td style="text-align: right;">   -0    </td><td style="text-align: right;">    0    </td><td style="text-align: right;"> 0.231</td><td style="text-align: right;">   -0.001</td></tr>
# <tr><td style="text-align: right;">  -0    </td><td style="text-align: right;">    1.006</td><td style="text-align: right;">    0    </td><td style="text-align: right;">  -0    </td><td style="text-align: right;">    0.406</td><td style="text-align: right;">    0    </td><td style="text-align: right;">-0.001</td><td style="text-align: right;">   -0.001</td></tr>
# <tr><td style="text-align: right;">  -0    </td><td style="text-align: right;">    0    </td><td style="text-align: right;">    1.003</td><td style="text-align: right;">  -0    </td><td style="text-align: right;">    0.001</td><td style="text-align: right;">   -0.268</td><td style="text-align: right;"> 0.001</td><td style="text-align: right;">   -0.184</td></tr>
# <tr><td style="text-align: right;">   0.308</td><td style="text-align: right;">   -0    </td><td style="text-align: right;">   -0    </td><td style="text-align: right;">   0.428</td><td style="text-align: right;">   -0    </td><td style="text-align: right;">    0    </td><td style="text-align: right;"> 0.08 </td><td style="text-align: right;">   -0.001</td></tr>
# <tr><td style="text-align: right;">  -0    </td><td style="text-align: right;">    0.406</td><td style="text-align: right;">    0.001</td><td style="text-align: right;">  -0    </td><td style="text-align: right;">    1.006</td><td style="text-align: right;">   -0    </td><td style="text-align: right;"> 0    </td><td style="text-align: right;">   -0    </td></tr>
# <tr><td style="text-align: right;">   0    </td><td style="text-align: right;">    0    </td><td style="text-align: right;">   -0.268</td><td style="text-align: right;">   0    </td><td style="text-align: right;">   -0    </td><td style="text-align: right;">    1.003</td><td style="text-align: right;"> 0    </td><td style="text-align: right;">   -0.034</td></tr>
# <tr><td style="text-align: right;">   0.231</td><td style="text-align: right;">   -0.001</td><td style="text-align: right;">    0.001</td><td style="text-align: right;">   0.08 </td><td style="text-align: right;">    0    </td><td style="text-align: right;">    0    </td><td style="text-align: right;"> 0.762</td><td style="text-align: right;">   -0.002</td></tr>
# <tr><td style="text-align: right;">  -0.001</td><td style="text-align: right;">   -0.001</td><td style="text-align: right;">   -0.184</td><td style="text-align: right;">  -0.001</td><td style="text-align: right;">   -0    </td><td style="text-align: right;">   -0.034</td><td style="text-align: right;">-0.002</td><td style="text-align: right;">    1.003</td></tr>
# </tbody>
# </table>
# <table>
# <thead>
# <tr><th style="text-align: right;">  l_1_pT</th><th style="text-align: right;">  l_1_eta</th><th style="text-align: right;">  l_1_phi</th><th style="text-align: right;">  l_2_pT</th><th style="text-align: right;">  l_2_eta</th><th style="text-align: right;">  l_2_phi</th><th style="text-align: right;">   MET</th><th style="text-align: right;">  MET_phi</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">   1    </td><td style="text-align: right;">   -0    </td><td style="text-align: right;">   -0    </td><td style="text-align: right;">   0.685</td><td style="text-align: right;">   -0    </td><td style="text-align: right;">    0    </td><td style="text-align: right;"> 0.385</td><td style="text-align: right;">   -0.001</td></tr>
# <tr><td style="text-align: right;">  -0    </td><td style="text-align: right;">    1    </td><td style="text-align: right;">    0    </td><td style="text-align: right;">  -0.001</td><td style="text-align: right;">    0.403</td><td style="text-align: right;">    0    </td><td style="text-align: right;">-0.001</td><td style="text-align: right;">   -0.001</td></tr>
# <tr><td style="text-align: right;">  -0    </td><td style="text-align: right;">    0    </td><td style="text-align: right;">    1    </td><td style="text-align: right;">  -0    </td><td style="text-align: right;">    0.001</td><td style="text-align: right;">   -0.267</td><td style="text-align: right;"> 0.001</td><td style="text-align: right;">   -0.184</td></tr>
# <tr><td style="text-align: right;">   0.685</td><td style="text-align: right;">   -0.001</td><td style="text-align: right;">   -0    </td><td style="text-align: right;">   1    </td><td style="text-align: right;">   -0.001</td><td style="text-align: right;">    0    </td><td style="text-align: right;"> 0.14 </td><td style="text-align: right;">   -0.002</td></tr>
# <tr><td style="text-align: right;">  -0    </td><td style="text-align: right;">    0.403</td><td style="text-align: right;">    0.001</td><td style="text-align: right;">  -0.001</td><td style="text-align: right;">    1    </td><td style="text-align: right;">   -0    </td><td style="text-align: right;"> 0    </td><td style="text-align: right;">   -0    </td></tr>
# <tr><td style="text-align: right;">   0    </td><td style="text-align: right;">    0    </td><td style="text-align: right;">   -0.267</td><td style="text-align: right;">   0    </td><td style="text-align: right;">   -0    </td><td style="text-align: right;">    1    </td><td style="text-align: right;"> 0    </td><td style="text-align: right;">   -0.034</td></tr>
# <tr><td style="text-align: right;">   0.385</td><td style="text-align: right;">   -0.001</td><td style="text-align: right;">    0.001</td><td style="text-align: right;">   0.14 </td><td style="text-align: right;">    0    </td><td style="text-align: right;">    0    </td><td style="text-align: right;"> 1    </td><td style="text-align: right;">   -0.002</td></tr>
# <tr><td style="text-align: right;">  -0.001</td><td style="text-align: right;">   -0.001</td><td style="text-align: right;">   -0.184</td><td style="text-align: right;">  -0.002</td><td style="text-align: right;">   -0    </td><td style="text-align: right;">   -0.034</td><td style="text-align: right;">-0.002</td><td style="text-align: right;">    1    </td></tr>
# </tbody>
# </table>
# High-level Derived Features
# <table>
# <thead>
# <tr><th style="text-align: right;">  dPhi_r_b</th><th style="text-align: right;">  cos_theta_r1</th><th style="text-align: right;">   MT2</th><th style="text-align: right;">   S_R</th><th style="text-align: right;">   M_R</th><th style="text-align: right;">     R</th><th style="text-align: right;">  MET_rel</th><th style="text-align: right;">  M_TR_2</th><th style="text-align: right;">  axial_MET</th><th style="text-align: right;">  M_Delta_R</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0.19 </td><td style="text-align: right;">         0.009</td><td style="text-align: right;"> 0.021</td><td style="text-align: right;">-0.004</td><td style="text-align: right;">-0.029</td><td style="text-align: right;"> 0.087</td><td style="text-align: right;">    0.147</td><td style="text-align: right;">   0.058</td><td style="text-align: right;">     -0.026</td><td style="text-align: right;">      0.042</td></tr>
# <tr><td style="text-align: right;">     0.009</td><td style="text-align: right;">         0.039</td><td style="text-align: right;"> 0.045</td><td style="text-align: right;">-0.01 </td><td style="text-align: right;">-0.014</td><td style="text-align: right;"> 0.058</td><td style="text-align: right;">    0.056</td><td style="text-align: right;">   0.052</td><td style="text-align: right;">     -0.054</td><td style="text-align: right;">      0.039</td></tr>
# <tr><td style="text-align: right;">     0.021</td><td style="text-align: right;">         0.045</td><td style="text-align: right;"> 0.738</td><td style="text-align: right;">-0.011</td><td style="text-align: right;">-0.037</td><td style="text-align: right;"> 0.232</td><td style="text-align: right;">    0.41 </td><td style="text-align: right;">   0.189</td><td style="text-align: right;">     -0.46 </td><td style="text-align: right;">      0.433</td></tr>
# <tr><td style="text-align: right;">    -0.004</td><td style="text-align: right;">        -0.01 </td><td style="text-align: right;">-0.011</td><td style="text-align: right;"> 0.385</td><td style="text-align: right;"> 0.383</td><td style="text-align: right;">-0.083</td><td style="text-align: right;">    0.082</td><td style="text-align: right;">   0.23 </td><td style="text-align: right;">     -0.043</td><td style="text-align: right;">      0.096</td></tr>
# <tr><td style="text-align: right;">    -0.029</td><td style="text-align: right;">        -0.014</td><td style="text-align: right;">-0.037</td><td style="text-align: right;"> 0.383</td><td style="text-align: right;"> 0.395</td><td style="text-align: right;">-0.113</td><td style="text-align: right;">    0.044</td><td style="text-align: right;">   0.212</td><td style="text-align: right;">      0.015</td><td style="text-align: right;">      0.074</td></tr>
# <tr><td style="text-align: right;">     0.087</td><td style="text-align: right;">         0.058</td><td style="text-align: right;"> 0.232</td><td style="text-align: right;">-0.083</td><td style="text-align: right;">-0.113</td><td style="text-align: right;"> 0.222</td><td style="text-align: right;">    0.25 </td><td style="text-align: right;">   0.104</td><td style="text-align: right;">     -0.182</td><td style="text-align: right;">      0.166</td></tr>
# <tr><td style="text-align: right;">     0.147</td><td style="text-align: right;">         0.056</td><td style="text-align: right;"> 0.41 </td><td style="text-align: right;"> 0.082</td><td style="text-align: right;"> 0.044</td><td style="text-align: right;"> 0.25 </td><td style="text-align: right;">    0.792</td><td style="text-align: right;">   0.303</td><td style="text-align: right;">     -0.125</td><td style="text-align: right;">      0.416</td></tr>
# <tr><td style="text-align: right;">     0.058</td><td style="text-align: right;">         0.052</td><td style="text-align: right;"> 0.189</td><td style="text-align: right;"> 0.23 </td><td style="text-align: right;"> 0.212</td><td style="text-align: right;"> 0.104</td><td style="text-align: right;">    0.303</td><td style="text-align: right;">   0.341</td><td style="text-align: right;">     -0.189</td><td style="text-align: right;">      0.242</td></tr>
# <tr><td style="text-align: right;">    -0.026</td><td style="text-align: right;">        -0.054</td><td style="text-align: right;">-0.46 </td><td style="text-align: right;">-0.043</td><td style="text-align: right;"> 0.015</td><td style="text-align: right;">-0.182</td><td style="text-align: right;">   -0.125</td><td style="text-align: right;">  -0.189</td><td style="text-align: right;">      1.003</td><td style="text-align: right;">     -0.234</td></tr>
# <tr><td style="text-align: right;">     0.042</td><td style="text-align: right;">         0.039</td><td style="text-align: right;"> 0.433</td><td style="text-align: right;"> 0.096</td><td style="text-align: right;"> 0.074</td><td style="text-align: right;"> 0.166</td><td style="text-align: right;">    0.416</td><td style="text-align: right;">   0.242</td><td style="text-align: right;">     -0.234</td><td style="text-align: right;">      0.389</td></tr>
# </tbody>
# </table>
# <table>
# <thead>
# <tr><th style="text-align: right;">  dPhi_r_b</th><th style="text-align: right;">  cos_theta_r1</th><th style="text-align: right;">   MT2</th><th style="text-align: right;">   S_R</th><th style="text-align: right;">   M_R</th><th style="text-align: right;">     R</th><th style="text-align: right;">  MET_rel</th><th style="text-align: right;">  M_TR_2</th><th style="text-align: right;">  axial_MET</th><th style="text-align: right;">  M_Delta_R</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     1    </td><td style="text-align: right;">         0.106</td><td style="text-align: right;"> 0.056</td><td style="text-align: right;">-0.013</td><td style="text-align: right;">-0.106</td><td style="text-align: right;"> 0.424</td><td style="text-align: right;">    0.378</td><td style="text-align: right;">   0.228</td><td style="text-align: right;">     -0.06 </td><td style="text-align: right;">      0.156</td></tr>
# <tr><td style="text-align: right;">     0.106</td><td style="text-align: right;">         1    </td><td style="text-align: right;"> 0.263</td><td style="text-align: right;">-0.084</td><td style="text-align: right;">-0.115</td><td style="text-align: right;"> 0.627</td><td style="text-align: right;">    0.317</td><td style="text-align: right;">   0.451</td><td style="text-align: right;">     -0.274</td><td style="text-align: right;">      0.319</td></tr>
# <tr><td style="text-align: right;">     0.056</td><td style="text-align: right;">         0.263</td><td style="text-align: right;"> 1    </td><td style="text-align: right;">-0.021</td><td style="text-align: right;">-0.068</td><td style="text-align: right;"> 0.574</td><td style="text-align: right;">    0.536</td><td style="text-align: right;">   0.378</td><td style="text-align: right;">     -0.535</td><td style="text-align: right;">      0.808</td></tr>
# <tr><td style="text-align: right;">    -0.013</td><td style="text-align: right;">        -0.084</td><td style="text-align: right;">-0.021</td><td style="text-align: right;"> 1    </td><td style="text-align: right;"> 0.981</td><td style="text-align: right;">-0.285</td><td style="text-align: right;">    0.149</td><td style="text-align: right;">   0.636</td><td style="text-align: right;">     -0.07 </td><td style="text-align: right;">      0.248</td></tr>
# <tr><td style="text-align: right;">    -0.106</td><td style="text-align: right;">        -0.115</td><td style="text-align: right;">-0.068</td><td style="text-align: right;"> 0.981</td><td style="text-align: right;"> 1    </td><td style="text-align: right;">-0.381</td><td style="text-align: right;">    0.078</td><td style="text-align: right;">   0.578</td><td style="text-align: right;">      0.024</td><td style="text-align: right;">      0.189</td></tr>
# <tr><td style="text-align: right;">     0.424</td><td style="text-align: right;">         0.627</td><td style="text-align: right;"> 0.574</td><td style="text-align: right;">-0.285</td><td style="text-align: right;">-0.381</td><td style="text-align: right;"> 1    </td><td style="text-align: right;">    0.595</td><td style="text-align: right;">   0.38 </td><td style="text-align: right;">     -0.385</td><td style="text-align: right;">      0.564</td></tr>
# <tr><td style="text-align: right;">     0.378</td><td style="text-align: right;">         0.317</td><td style="text-align: right;"> 0.536</td><td style="text-align: right;"> 0.149</td><td style="text-align: right;"> 0.078</td><td style="text-align: right;"> 0.595</td><td style="text-align: right;">    1    </td><td style="text-align: right;">   0.583</td><td style="text-align: right;">     -0.141</td><td style="text-align: right;">      0.749</td></tr>
# <tr><td style="text-align: right;">     0.228</td><td style="text-align: right;">         0.451</td><td style="text-align: right;"> 0.378</td><td style="text-align: right;"> 0.636</td><td style="text-align: right;"> 0.578</td><td style="text-align: right;"> 0.38 </td><td style="text-align: right;">    0.583</td><td style="text-align: right;">   1    </td><td style="text-align: right;">     -0.323</td><td style="text-align: right;">      0.666</td></tr>
# <tr><td style="text-align: right;">    -0.06 </td><td style="text-align: right;">        -0.274</td><td style="text-align: right;">-0.535</td><td style="text-align: right;">-0.07 </td><td style="text-align: right;"> 0.024</td><td style="text-align: right;">-0.385</td><td style="text-align: right;">   -0.141</td><td style="text-align: right;">  -0.323</td><td style="text-align: right;">      1    </td><td style="text-align: right;">     -0.375</td></tr>
# <tr><td style="text-align: right;">     0.156</td><td style="text-align: right;">         0.319</td><td style="text-align: right;"> 0.808</td><td style="text-align: right;"> 0.248</td><td style="text-align: right;"> 0.189</td><td style="text-align: right;"> 0.564</td><td style="text-align: right;">    0.749</td><td style="text-align: right;">   0.666</td><td style="text-align: right;">     -0.375</td><td style="text-align: right;">      1    </td></tr>
# </tbody>
# </table>

# %%
def cov_corr_tables(df, feature_list, title):  
    features = df[feature_list].values.T  # Convert feature columns to numpy array and transpose (features x samples)
    cov_matrix = np.cov(features).round(3) # Covariance matrix raw variance/covariance between features
    corr_matrix = np.corrcoef(features).round(3) # Correlation matrix - normalized -1 to +1 scale
    
    display(HTML(tabulate.tabulate(cov_matrix, tablefmt='html', headers=feature_list))) # HTML table for covariance with feature names as column headers
    display(HTML(tabulate.tabulate(corr_matrix, tablefmt='html', headers=feature_list)))     # HTML table for correlation with feature names as column headers

# Test 
cov_corr_tables(df, RawNames, "Low-level Raw Features")
cov_corr_tables(df, FeatureNames, "High-level Derived Features")
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  l_1_pT</th><th style="text-align: right;">  l_1_eta</th><th style="text-align: right;">  l_1_phi</th><th style="text-align: right;">  l_2_pT</th><th style="text-align: right;">  l_2_eta</th><th style="text-align: right;">  l_2_phi</th><th style="text-align: right;">   MET</th><th style="text-align: right;">  MET_phi</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">   0.472</td><td style="text-align: right;">   -0    </td><td style="text-align: right;">   -0    </td><td style="text-align: right;">   0.308</td><td style="text-align: right;">   -0    </td><td style="text-align: right;">    0    </td><td style="text-align: right;"> 0.231</td><td style="text-align: right;">   -0.001</td></tr>
# <tr><td style="text-align: right;">  -0    </td><td style="text-align: right;">    1.006</td><td style="text-align: right;">    0    </td><td style="text-align: right;">  -0    </td><td style="text-align: right;">    0.406</td><td style="text-align: right;">    0    </td><td style="text-align: right;">-0.001</td><td style="text-align: right;">   -0.001</td></tr>
# <tr><td style="text-align: right;">  -0    </td><td style="text-align: right;">    0    </td><td style="text-align: right;">    1.003</td><td style="text-align: right;">  -0    </td><td style="text-align: right;">    0.001</td><td style="text-align: right;">   -0.268</td><td style="text-align: right;"> 0.001</td><td style="text-align: right;">   -0.184</td></tr>
# <tr><td style="text-align: right;">   0.308</td><td style="text-align: right;">   -0    </td><td style="text-align: right;">   -0    </td><td style="text-align: right;">   0.428</td><td style="text-align: right;">   -0    </td><td style="text-align: right;">    0    </td><td style="text-align: right;"> 0.08 </td><td style="text-align: right;">   -0.001</td></tr>
# <tr><td style="text-align: right;">  -0    </td><td style="text-align: right;">    0.406</td><td style="text-align: right;">    0.001</td><td style="text-align: right;">  -0    </td><td style="text-align: right;">    1.006</td><td style="text-align: right;">   -0    </td><td style="text-align: right;"> 0    </td><td style="text-align: right;">   -0    </td></tr>
# <tr><td style="text-align: right;">   0    </td><td style="text-align: right;">    0    </td><td style="text-align: right;">   -0.268</td><td style="text-align: right;">   0    </td><td style="text-align: right;">   -0    </td><td style="text-align: right;">    1.003</td><td style="text-align: right;"> 0    </td><td style="text-align: right;">   -0.034</td></tr>
# <tr><td style="text-align: right;">   0.231</td><td style="text-align: right;">   -0.001</td><td style="text-align: right;">    0.001</td><td style="text-align: right;">   0.08 </td><td style="text-align: right;">    0    </td><td style="text-align: right;">    0    </td><td style="text-align: right;"> 0.762</td><td style="text-align: right;">   -0.002</td></tr>
# <tr><td style="text-align: right;">  -0.001</td><td style="text-align: right;">   -0.001</td><td style="text-align: right;">   -0.184</td><td style="text-align: right;">  -0.001</td><td style="text-align: right;">   -0    </td><td style="text-align: right;">   -0.034</td><td style="text-align: right;">-0.002</td><td style="text-align: right;">    1.003</td></tr>
# </tbody>
# </table>
# <table>
# <thead>
# <tr><th style="text-align: right;">  l_1_pT</th><th style="text-align: right;">  l_1_eta</th><th style="text-align: right;">  l_1_phi</th><th style="text-align: right;">  l_2_pT</th><th style="text-align: right;">  l_2_eta</th><th style="text-align: right;">  l_2_phi</th><th style="text-align: right;">   MET</th><th style="text-align: right;">  MET_phi</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">   1    </td><td style="text-align: right;">   -0    </td><td style="text-align: right;">   -0    </td><td style="text-align: right;">   0.685</td><td style="text-align: right;">   -0    </td><td style="text-align: right;">    0    </td><td style="text-align: right;"> 0.385</td><td style="text-align: right;">   -0.001</td></tr>
# <tr><td style="text-align: right;">  -0    </td><td style="text-align: right;">    1    </td><td style="text-align: right;">    0    </td><td style="text-align: right;">  -0.001</td><td style="text-align: right;">    0.403</td><td style="text-align: right;">    0    </td><td style="text-align: right;">-0.001</td><td style="text-align: right;">   -0.001</td></tr>
# <tr><td style="text-align: right;">  -0    </td><td style="text-align: right;">    0    </td><td style="text-align: right;">    1    </td><td style="text-align: right;">  -0    </td><td style="text-align: right;">    0.001</td><td style="text-align: right;">   -0.267</td><td style="text-align: right;"> 0.001</td><td style="text-align: right;">   -0.184</td></tr>
# <tr><td style="text-align: right;">   0.685</td><td style="text-align: right;">   -0.001</td><td style="text-align: right;">   -0    </td><td style="text-align: right;">   1    </td><td style="text-align: right;">   -0.001</td><td style="text-align: right;">    0    </td><td style="text-align: right;"> 0.14 </td><td style="text-align: right;">   -0.002</td></tr>
# <tr><td style="text-align: right;">  -0    </td><td style="text-align: right;">    0.403</td><td style="text-align: right;">    0.001</td><td style="text-align: right;">  -0.001</td><td style="text-align: right;">    1    </td><td style="text-align: right;">   -0    </td><td style="text-align: right;"> 0    </td><td style="text-align: right;">   -0    </td></tr>
# <tr><td style="text-align: right;">   0    </td><td style="text-align: right;">    0    </td><td style="text-align: right;">   -0.267</td><td style="text-align: right;">   0    </td><td style="text-align: right;">   -0    </td><td style="text-align: right;">    1    </td><td style="text-align: right;"> 0    </td><td style="text-align: right;">   -0.034</td></tr>
# <tr><td style="text-align: right;">   0.385</td><td style="text-align: right;">   -0.001</td><td style="text-align: right;">    0.001</td><td style="text-align: right;">   0.14 </td><td style="text-align: right;">    0    </td><td style="text-align: right;">    0    </td><td style="text-align: right;"> 1    </td><td style="text-align: right;">   -0.002</td></tr>
# <tr><td style="text-align: right;">  -0.001</td><td style="text-align: right;">   -0.001</td><td style="text-align: right;">   -0.184</td><td style="text-align: right;">  -0.002</td><td style="text-align: right;">   -0    </td><td style="text-align: right;">   -0.034</td><td style="text-align: right;">-0.002</td><td style="text-align: right;">    1    </td></tr>
# </tbody>
# </table>
# <table>
# <thead>
# <tr><th style="text-align: right;">  dPhi_r_b</th><th style="text-align: right;">  cos_theta_r1</th><th style="text-align: right;">   MT2</th><th style="text-align: right;">   S_R</th><th style="text-align: right;">   M_R</th><th style="text-align: right;">     R</th><th style="text-align: right;">  MET_rel</th><th style="text-align: right;">  M_TR_2</th><th style="text-align: right;">  axial_MET</th><th style="text-align: right;">  M_Delta_R</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0.19 </td><td style="text-align: right;">         0.009</td><td style="text-align: right;"> 0.021</td><td style="text-align: right;">-0.004</td><td style="text-align: right;">-0.029</td><td style="text-align: right;"> 0.087</td><td style="text-align: right;">    0.147</td><td style="text-align: right;">   0.058</td><td style="text-align: right;">     -0.026</td><td style="text-align: right;">      0.042</td></tr>
# <tr><td style="text-align: right;">     0.009</td><td style="text-align: right;">         0.039</td><td style="text-align: right;"> 0.045</td><td style="text-align: right;">-0.01 </td><td style="text-align: right;">-0.014</td><td style="text-align: right;"> 0.058</td><td style="text-align: right;">    0.056</td><td style="text-align: right;">   0.052</td><td style="text-align: right;">     -0.054</td><td style="text-align: right;">      0.039</td></tr>
# <tr><td style="text-align: right;">     0.021</td><td style="text-align: right;">         0.045</td><td style="text-align: right;"> 0.738</td><td style="text-align: right;">-0.011</td><td style="text-align: right;">-0.037</td><td style="text-align: right;"> 0.232</td><td style="text-align: right;">    0.41 </td><td style="text-align: right;">   0.189</td><td style="text-align: right;">     -0.46 </td><td style="text-align: right;">      0.433</td></tr>
# <tr><td style="text-align: right;">    -0.004</td><td style="text-align: right;">        -0.01 </td><td style="text-align: right;">-0.011</td><td style="text-align: right;"> 0.385</td><td style="text-align: right;"> 0.383</td><td style="text-align: right;">-0.083</td><td style="text-align: right;">    0.082</td><td style="text-align: right;">   0.23 </td><td style="text-align: right;">     -0.043</td><td style="text-align: right;">      0.096</td></tr>
# <tr><td style="text-align: right;">    -0.029</td><td style="text-align: right;">        -0.014</td><td style="text-align: right;">-0.037</td><td style="text-align: right;"> 0.383</td><td style="text-align: right;"> 0.395</td><td style="text-align: right;">-0.113</td><td style="text-align: right;">    0.044</td><td style="text-align: right;">   0.212</td><td style="text-align: right;">      0.015</td><td style="text-align: right;">      0.074</td></tr>
# <tr><td style="text-align: right;">     0.087</td><td style="text-align: right;">         0.058</td><td style="text-align: right;"> 0.232</td><td style="text-align: right;">-0.083</td><td style="text-align: right;">-0.113</td><td style="text-align: right;"> 0.222</td><td style="text-align: right;">    0.25 </td><td style="text-align: right;">   0.104</td><td style="text-align: right;">     -0.182</td><td style="text-align: right;">      0.166</td></tr>
# <tr><td style="text-align: right;">     0.147</td><td style="text-align: right;">         0.056</td><td style="text-align: right;"> 0.41 </td><td style="text-align: right;"> 0.082</td><td style="text-align: right;"> 0.044</td><td style="text-align: right;"> 0.25 </td><td style="text-align: right;">    0.792</td><td style="text-align: right;">   0.303</td><td style="text-align: right;">     -0.125</td><td style="text-align: right;">      0.416</td></tr>
# <tr><td style="text-align: right;">     0.058</td><td style="text-align: right;">         0.052</td><td style="text-align: right;"> 0.189</td><td style="text-align: right;"> 0.23 </td><td style="text-align: right;"> 0.212</td><td style="text-align: right;"> 0.104</td><td style="text-align: right;">    0.303</td><td style="text-align: right;">   0.341</td><td style="text-align: right;">     -0.189</td><td style="text-align: right;">      0.242</td></tr>
# <tr><td style="text-align: right;">    -0.026</td><td style="text-align: right;">        -0.054</td><td style="text-align: right;">-0.46 </td><td style="text-align: right;">-0.043</td><td style="text-align: right;"> 0.015</td><td style="text-align: right;">-0.182</td><td style="text-align: right;">   -0.125</td><td style="text-align: right;">  -0.189</td><td style="text-align: right;">      1.003</td><td style="text-align: right;">     -0.234</td></tr>
# <tr><td style="text-align: right;">     0.042</td><td style="text-align: right;">         0.039</td><td style="text-align: right;"> 0.433</td><td style="text-align: right;"> 0.096</td><td style="text-align: right;"> 0.074</td><td style="text-align: right;"> 0.166</td><td style="text-align: right;">    0.416</td><td style="text-align: right;">   0.242</td><td style="text-align: right;">     -0.234</td><td style="text-align: right;">      0.389</td></tr>
# </tbody>
# </table>
# <table>
# <thead>
# <tr><th style="text-align: right;">  dPhi_r_b</th><th style="text-align: right;">  cos_theta_r1</th><th style="text-align: right;">   MT2</th><th style="text-align: right;">   S_R</th><th style="text-align: right;">   M_R</th><th style="text-align: right;">     R</th><th style="text-align: right;">  MET_rel</th><th style="text-align: right;">  M_TR_2</th><th style="text-align: right;">  axial_MET</th><th style="text-align: right;">  M_Delta_R</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     1    </td><td style="text-align: right;">         0.106</td><td style="text-align: right;"> 0.056</td><td style="text-align: right;">-0.013</td><td style="text-align: right;">-0.106</td><td style="text-align: right;"> 0.424</td><td style="text-align: right;">    0.378</td><td style="text-align: right;">   0.228</td><td style="text-align: right;">     -0.06 </td><td style="text-align: right;">      0.156</td></tr>
# <tr><td style="text-align: right;">     0.106</td><td style="text-align: right;">         1    </td><td style="text-align: right;"> 0.263</td><td style="text-align: right;">-0.084</td><td style="text-align: right;">-0.115</td><td style="text-align: right;"> 0.627</td><td style="text-align: right;">    0.317</td><td style="text-align: right;">   0.451</td><td style="text-align: right;">     -0.274</td><td style="text-align: right;">      0.319</td></tr>
# <tr><td style="text-align: right;">     0.056</td><td style="text-align: right;">         0.263</td><td style="text-align: right;"> 1    </td><td style="text-align: right;">-0.021</td><td style="text-align: right;">-0.068</td><td style="text-align: right;"> 0.574</td><td style="text-align: right;">    0.536</td><td style="text-align: right;">   0.378</td><td style="text-align: right;">     -0.535</td><td style="text-align: right;">      0.808</td></tr>
# <tr><td style="text-align: right;">    -0.013</td><td style="text-align: right;">        -0.084</td><td style="text-align: right;">-0.021</td><td style="text-align: right;"> 1    </td><td style="text-align: right;"> 0.981</td><td style="text-align: right;">-0.285</td><td style="text-align: right;">    0.149</td><td style="text-align: right;">   0.636</td><td style="text-align: right;">     -0.07 </td><td style="text-align: right;">      0.248</td></tr>
# <tr><td style="text-align: right;">    -0.106</td><td style="text-align: right;">        -0.115</td><td style="text-align: right;">-0.068</td><td style="text-align: right;"> 0.981</td><td style="text-align: right;"> 1    </td><td style="text-align: right;">-0.381</td><td style="text-align: right;">    0.078</td><td style="text-align: right;">   0.578</td><td style="text-align: right;">      0.024</td><td style="text-align: right;">      0.189</td></tr>
# <tr><td style="text-align: right;">     0.424</td><td style="text-align: right;">         0.627</td><td style="text-align: right;"> 0.574</td><td style="text-align: right;">-0.285</td><td style="text-align: right;">-0.381</td><td style="text-align: right;"> 1    </td><td style="text-align: right;">    0.595</td><td style="text-align: right;">   0.38 </td><td style="text-align: right;">     -0.385</td><td style="text-align: right;">      0.564</td></tr>
# <tr><td style="text-align: right;">     0.378</td><td style="text-align: right;">         0.317</td><td style="text-align: right;"> 0.536</td><td style="text-align: right;"> 0.149</td><td style="text-align: right;"> 0.078</td><td style="text-align: right;"> 0.595</td><td style="text-align: right;">    1    </td><td style="text-align: right;">   0.583</td><td style="text-align: right;">     -0.141</td><td style="text-align: right;">      0.749</td></tr>
# <tr><td style="text-align: right;">     0.228</td><td style="text-align: right;">         0.451</td><td style="text-align: right;"> 0.378</td><td style="text-align: right;"> 0.636</td><td style="text-align: right;"> 0.578</td><td style="text-align: right;"> 0.38 </td><td style="text-align: right;">    0.583</td><td style="text-align: right;">   1    </td><td style="text-align: right;">     -0.323</td><td style="text-align: right;">      0.666</td></tr>
# <tr><td style="text-align: right;">    -0.06 </td><td style="text-align: right;">        -0.274</td><td style="text-align: right;">-0.535</td><td style="text-align: right;">-0.07 </td><td style="text-align: right;"> 0.024</td><td style="text-align: right;">-0.385</td><td style="text-align: right;">   -0.141</td><td style="text-align: right;">  -0.323</td><td style="text-align: right;">      1    </td><td style="text-align: right;">     -0.375</td></tr>
# <tr><td style="text-align: right;">     0.156</td><td style="text-align: right;">         0.319</td><td style="text-align: right;"> 0.808</td><td style="text-align: right;"> 0.248</td><td style="text-align: right;"> 0.189</td><td style="text-align: right;"> 0.564</td><td style="text-align: right;">    0.749</td><td style="text-align: right;">   0.666</td><td style="text-align: right;">     -0.375</td><td style="text-align: right;">      1    </td></tr>
# </tbody>
# </table>

# %% [markdown]
# Hint: Example code for embedding a `tabulate` table into a notebook:

# %%
from IPython.display import HTML, display
import tabulate
table = [["A",1,2],
        ["C",3,4],
        ["D",5,6]]
display(HTML(tabulate.tabulate(table, tablefmt='html', headers=["X","Y","Z"])))
# Out:
# <table>
# <thead>
# <tr><th>X  </th><th style="text-align: right;">  Y</th><th style="text-align: right;">  Z</th></tr>
# </thead>
# <tbody>
# <tr><td>A  </td><td style="text-align: right;">  1</td><td style="text-align: right;">  2</td></tr>
# <tr><td>C  </td><td style="text-align: right;">  3</td><td style="text-align: right;">  4</td></tr>
# <tr><td>D  </td><td style="text-align: right;">  5</td><td style="text-align: right;">  6</td></tr>
# </tbody>
# </table>

# %% [markdown]
# ## Exercise 5: Selection
#
# ### Exercise 5.1
#
# Part a
# By looking at the signal/background distributions for each observable (e.g. $x$) determine which selection criteria would be optimal:
#
# 1. $x > x_c$
# 2. $x < x_c$
# 3. $|x - \mu| > x_c$
# 4. $|x - \mu| < x_c$
#
# where $x_c$ is value to be determined below.
#
# ### Exercise 5.2
#
# Plot the True Positive Rate (TPR) (aka signal efficiency $\epsilon_S(x_c)$) and False Positive Rate (FPR) (aka background efficiency $\epsilon_B(x_c)$) as function of $x_c$ for applying the strategy in part a to each observable.
#
# ### Exercise 5.3
# Assume 3 different scenarios corresponding to different numbers of signal and background events expected in data:
#
# 1. Expect $N_S=10$, $N_B=100$.
# 1. Expect $N_S=100$, $N_B=1000$.
# 1. Expect $N_S=1000$, $N_B=10000$.
# 1. Expect $N_S=10000$, $N_B=100000$.
#
# Plot the significance ($\sigma_{S'}$) for each observable as function of $x_c$ for each scenario, where
#
# $\sigma_{S'}= \frac{N'_S}{\sqrt{N'_S+N'_B}}$
#
# and $N'_{S,B} = \epsilon_{S,B}(x_c) * N_{S,B}$.

# %% [markdown]
# ## Exercise 6: Cut Flow
#
#
# ### Exercise 6.1
#
# For each above scenario, choose a subset (minumum 3) of observables to use for selections, and values of $x_c$ based on your significance plots (part 3c).
#
# ### Exercise 6.2
# Create a "cut-flow" table for each scenario where you successively make the selections on each observable and tabulate $\epsilon_S$, $\epsilon_B$, $N'_S$, $N'_B$, and $\sigma_{S'}$.
#
# ### Exercise 6.3
# In 3c above you computed the significance for each observable assuming to make no other selections on any other observable. If the variables are correlated, then this assumption can lead to non-optimial results when selecting on multiple variables. By looking at the correlation matrices and your answers to 4b, identify where this effect could be most detrimental to the significance. Attempt to correct the issue by applying the selection in one observable and then optimizing (part 3c) for a second observable. What happens if you change the order of your selection (make selection on second and optimize on first)?

# %% [markdown]
# ## Exercise 7: ROC Curves
#
# ### Exercise 7.1
# For the top 3 observables you identified earlier, create one figure overlaying the Reciever Operating Characteristic (ROC) curves for the 3 observables. Compute the area under the curves and report it in the legend of the figure.
#
# ### Exercise 7.2
# Write a function that you can use to quickly create the figure in part a with other observables and different conditions. Note that you will likely revise this function as you do the remainder of the lab.
#
# ### Exercise 7.3
# Use the function from part b to compare the ROC curves for the successive selections in lab 3, exercise 4. Specifically, plot the ROC curve after each selection.
#
# ### Exercise 7.4
# Use your function and appropriate example to demonstrate the effect (if any) of changing order of the successive selections.

# %% [markdown]
# ## Exercise 8: Linear Discriminant
#
# ### Exercise 8.1
#
# Using numpy, compute the between-class $\bf{S}_B$ and within-class $\bf{S}_W$ covariance matrices defined as:
#
# $$
# \bf{S}_B = (\bf{m_2}-\bf{m_1})(\bf{m_2}-\bf{m_1})^T \\
# $$
# $$
# \bf{S}_W = \sum_{i=1,2} \sum_{n=1}^{l_i} (\bf{x}_n^i - \bf{m}_i) (\bf{x}_n^i - \bf{m}_i)^T
# $$
#
# where $\bf{m_i}$ are the vectors containing the means for category 1 and 2, here defined as signal and background. Here $\bf{x}_n^i$ is the vector containing the observables for the $n$th example event in category $i$.
#
# ### Exercise 8.1
#
# Compute the linear coefficients $\bf{w} = \bf{S_W}^{-1}(\bf{m_2}-\bf{m_1})$. Compare the histogram of the distribution of $F_n^i=\bf{w}^T\bf{x}_n^i$ for the two categories.
#
# ### Exercise 8.1
#
# Draw the ROC curve for $F_n$.
#
# ### Exercise 8.1
#
# What is the maximal significance you can obtain in the scenarios in exercise 5?
